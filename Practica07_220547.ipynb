# %% [markdown]
# # PRACTICA 07_SQL

# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import pandas as pd
from sqlalchemy import create_engine

# %%
usuario = 'root'
contrasena = '12345'
host = 'localhost'
puerto = '3306'
base_datos = 'europe_soccer_fixed'

# %%
from sqlalchemy import create_engine
import pandas as pd

# Conexión al servidor MySQL
engine = create_engine('mysql+pymysql://root:12345@localhost:3306/europe_soccer_fixed', echo=True)

query = """
SELECT 
  id,
  team_fifa_api_id,
  team_api_id,
  date,
  buildUpPlaySpeed,
  buildUpPlaySpeedClass,
  buildUpPlayDribbling,
  buildUpPlayDribblingClass,
  buildUpPlayPassing,
  buildUpPlayPassingClass,
  buildUpPlayPositioningClass,
  chanceCreationPassing,
  chanceCreationPassingClass,
  chanceCreationCrossing,
  chanceCreationCrossingClass,
  chanceCreationShooting,
  chanceCreationShootingClass,
  chanceCreationPositioningClass,
  defencePressure,
  defencePressureClass,
  defenceAggression,
  defenceAggressionClass,
  defenceTeamWidth,
  defenceTeamWidthClass,
  defenceDefenderLineClass
FROM team_attributes;
"""

# Cargar los datos
df = pd.read_sql(query, engine)
df.head()
# Out:
# 2025-06-25 21:44:15,807 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2025-06-25 21:44:15,809 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-25 21:44:15,810 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2025-06-25 21:44:15,811 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-25 21:44:15,813 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2025-06-25 21:44:15,814 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-25 21:44:15,816 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-06-25 21:44:15,817 INFO sqlalchemy.engine.Engine DESCRIBE `europe_soccer_fixed`.`
# SELECT
#   id,
#   team_fifa_api_id,
#   team_api_id,
#   date,
#   buildUpPlaySpeed,
#   buildUpPlaySpeedClass,
#   buildUpPlayDribbling,
#   buildUpPlayDribblingClass,
#   buildUpPlayPassing,
#   buildUpPlayPassingClass,
#   buildUpPlayPositioningClass,
#   chanceCreationPassing,
#   chanceCreationPassingClass,
#   chanceCreationCrossing,
#   chanceCreationCrossingClass,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              1458 non-null   int64
#  1   team_fifa_api_id                1458 non-null   int64
#  2   team_api_id                     1458 non-null   int64
#  3   date                            1458 non-null   object
#  4   buildUpPlaySpeed                1458 non-null   int64
#  5   buildUpPlaySpeedClass           1458 non-null   object
#  6   buildUpPlayDribbling            1458 non-null   int64
#  7   buildUpPlayDribblingClass       1458 non-null   object
#  8   buildUpPlayPassing              1458 non-null   int64
#  9   buildUpPlayPassingClass         1458 non-null   object
#  10  buildUpPlayPositioningClass     1458 non-null   object
#  11  chanceCreationPassing           1458 non-null   int64
# ...

# %%
df.describe()
# Out:
#                 id  team_fifa_api_id    team_api_id  buildUpPlaySpeed  \
# count  1458.000000       1458.000000    1458.000000       1458.000000
# mean    729.500000      17706.982167    9995.727023         52.462277
# std     421.032659      39179.857739   13264.869900         11.545869
# min       1.000000          1.000000    1601.000000         20.000000
# 25%     365.250000        110.000000    8457.750000         45.000000
# 50%     729.500000        485.000000    8674.000000         52.000000
# 75%    1093.750000       1900.000000    9904.000000         62.000000
# max    1458.000000     112513.000000  274581.000000         80.000000
#
#        buildUpPlayDribbling  buildUpPlayPassing  chanceCreationPassing  \
# count           1458.000000         1458.000000            1458.000000
# mean              16.302469           48.490398              52.165295
# std               23.630152           10.896101              10.360793
# ...

# %%
df.isnull()
# Out:
#          id  team_fifa_api_id  team_api_id   date  buildUpPlaySpeed  \
# 0     False             False        False  False             False
# 1     False             False        False  False             False
# 2     False             False        False  False             False
# 3     False             False        False  False             False
# 4     False             False        False  False             False
# ...     ...               ...          ...    ...               ...
# 1453  False             False        False  False             False
# 1454  False             False        False  False             False
# 1455  False             False        False  False             False
# 1456  False             False        False  False             False
# 1457  False             False        False  False             False
#
#       buildUpPlaySpeedClass  buildUpPlayDribbling  buildUpPlayDribblingClass  \
# ...

# %%
df_notNull = df.dropna()

# %%
df_notNull_buildUpPlayDribbling = df.dropna(subset=['buildUpPlayDribbling'])

# %%
df_notNull_buildUpPlayDribbling.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              1458 non-null   int64
#  1   team_fifa_api_id                1458 non-null   int64
#  2   team_api_id                     1458 non-null   int64
#  3   date                            1458 non-null   object
#  4   buildUpPlaySpeed                1458 non-null   int64
#  5   buildUpPlaySpeedClass           1458 non-null   object
#  6   buildUpPlayDribbling            1458 non-null   int64
#  7   buildUpPlayDribblingClass       1458 non-null   object
#  8   buildUpPlayPassing              1458 non-null   int64
#  9   buildUpPlayPassingClass         1458 non-null   object
#  10  buildUpPlayPositioningClass     1458 non-null   object
#  11  chanceCreationPassing           1458 non-null   int64
# ...

# %%
df_duplicados_eliminados= df.drop_duplicates()

# %%
df_duplicados_eliminados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              1458 non-null   int64
#  1   team_fifa_api_id                1458 non-null   int64
#  2   team_api_id                     1458 non-null   int64
#  3   date                            1458 non-null   object
#  4   buildUpPlaySpeed                1458 non-null   int64
#  5   buildUpPlaySpeedClass           1458 non-null   object
#  6   buildUpPlayDribbling            1458 non-null   int64
#  7   buildUpPlayDribblingClass       1458 non-null   object
#  8   buildUpPlayPassing              1458 non-null   int64
#  9   buildUpPlayPassingClass         1458 non-null   object
#  10  buildUpPlayPositioningClass     1458 non-null   object
#  11  chanceCreationPassing           1458 non-null   int64
# ...

# %%
df_NullSustituido = df.fillna({'buildUpPlayDribbling':0,'buildUpPlaySpeed':0, 'buildUpPlayPassing':0})

# %%
df_NullSustituido
# Out:
#         id  team_fifa_api_id  team_api_id        date  buildUpPlaySpeed  \
# 0        1               434         9930  2010-02-22                60
# 1        2               434         9930  2014-09-19                52
# 2        3               434         9930  2015-09-10                47
# 3        4                77         8485  2010-02-22                70
# 4        5                77         8485  2011-02-22                47
# ...    ...               ...          ...         ...               ...
# 1453  1454             15005        10000  2011-02-22                52
# 1454  1455             15005        10000  2012-02-22                54
# 1455  1456             15005        10000  2013-09-20                54
# 1456  1457             15005        10000  2014-09-19                54
# 1457  1458             15005        10000  2015-09-10                54
#
#      buildUpPlaySpeedClass  buildUpPlayDribbling buildUpPlayDribblingClass  \
# ...

# %%
from sqlalchemy import text

with engine.connect() as connection:
    connection.execute(text("""
        CREATE TEMPORARY TABLE temp_team_attributes (
            id INT,
            team_fifa_api_id INT,
            team_api_id INT,
            date DATE,
            buildUpPlaySpeed INT,
            buildUpPlaySpeedClass VARCHAR(50),
            buildUpPlayDribbling INT,
            buildUpPlayDribblingClass VARCHAR(50),
            buildUpPlayPassing INT,
            buildUpPlayPassingClass VARCHAR(50),
            buildUpPlayPositioningClass VARCHAR(50),
            chanceCreationPassing INT,
            chanceCreationPassingClass VARCHAR(50),
            chanceCreationCrossing INT,
            chanceCreationCrossingClass VARCHAR(50),
            chanceCreationShooting INT,
            chanceCreationShootingClass VARCHAR(50),
            chanceCreationPositioningClass VARCHAR(50),
            defencePressure INT,
            defencePressureClass VARCHAR(50),
            defenceAggression INT,
            defenceAggressionClass VARCHAR(50),
            defenceTeamWidth INT,
            defenceTeamWidthClass VARCHAR(50),
            defenceDefenderLineClass VARCHAR(50)
        );
    """))
# Out:
# 2025-06-25 21:56:36,552 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-06-25 21:56:36,552 INFO sqlalchemy.engine.Engine
#         CREATE TEMPORARY TABLE temp_team_attributes (
#             id INT,
#             team_fifa_api_id INT,
#             team_api_id INT,
#             date DATE,
#             buildUpPlaySpeed INT,
#             buildUpPlaySpeedClass VARCHAR(50),
#             buildUpPlayDribbling INT,
#             buildUpPlayDribblingClass VARCHAR(50),
#             buildUpPlayPassing INT,
#             buildUpPlayPassingClass VARCHAR(50),
#             buildUpPlayPositioningClass VARCHAR(50),
#             chanceCreationPassing INT,
#             chanceCreationPassingClass VARCHAR(50),
#             chanceCreationCrossing INT,
#             chanceCreationCrossingClass VARCHAR(50),
#             chanceCreationShooting INT,
#             chanceCreationShootingClass VARCHAR(50),
#             chanceCreationPositioningClass VARCHAR(50),
# ...

# %%
df_NullSustituido.to_sql(
    name='temp_team_attributes',
    con=engine,
    if_exists='append',
    index=False,
    method='multi'
)
# Out:
# 2025-06-25 21:57:14,168 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-06-25 21:57:14,171 INFO sqlalchemy.engine.Engine DESCRIBE `europe_soccer_fixed`.`temp_team_attributes`
# 2025-06-25 21:57:14,171 INFO sqlalchemy.engine.Engine [raw sql] {}
# ...

# %% [markdown]
# # PRACTICA 07_API

# %%
import requests
import pandas as pd

api_key="U0aMsRxwQMtcuPMhK3Tnl8i7TduejwNWOB8LzkED"

url = f"https://api.nasa.gov/planetary/apod?api_key={api_key}&count=10"
response = requests.get(url)
data = response.json()

df_nasa = pd.json_normalize(data)
df_nasa.head()
# Out:
#                  copyright        date  \
# 0  Kerry-Ann Lecky Hepburn  2021-03-18
# 1                      NaN  2020-01-26
# 2   \nMaryBeth Kiczenski\n  2022-04-13
# 3                      NaN  2025-06-07
# 4                      NaN  2003-09-12
#
#                                          explanation  \
# 0  Clouds of stardust drift through this deep sky...
# 1  Sometimes, even rovers on Mars stop to admire ...
# 2  What created Devils Tower? The origin of this ...
# 3  On the Mars rover's mission Sol 46 or Earth da...
# 4  A truly enormous collection of thousands of ga...
#
#                                                hdurl media_type  \
# 0  https://apod.nasa.gov/apod/image/2103/KerryLec...      image
# 1  https://apod.nasa.gov/apod/image/2001/HillsRid...      image
# 2  https://apod.nasa.gov/apod/image/2204/DevilsWa...      image
# 3  https://apod.nasa.gov/apod/image/2506/PIA24542...      image
# 4  https://apod.nasa.gov/apod/image/0309/perseus_...      image
#
# ...

# %%
# Eliminar duplicados (si es un DataFrame con múltiples días)
df_nasa_clean = df_nasa.drop_duplicates()

# Verificar valores nulos (columnas típicas de la API APOD)
print(df_nasa_clean.isnull().sum())

# Eliminar registros sin 'title' o 'url' (ejemplo)
df_nasa_clean = df_nasa_clean.dropna(subset=["title", "url", "explanation"])

df_nasa_clean.shape
# Out:
# copyright          7
# date               0
# explanation        0
# hdurl              1
# media_type         0
# service_version    0
# title              0
# url                0
# dtype: int64
# (10, 8)

# %%
# Ejemplo: Procesar columnas existentes en df_nasa
df_nasa["date"] = pd.to_datetime(df_nasa["date"])  # Convertir fecha
df_nasa["year"] = df_nasa["date"].dt.year  # Extraer año

# Seleccionar columnas relevantes
df_extraction = df_nasa[["title", "date", "year", "url", "explanation"]]
print(df_extraction.head())
# Out:
#                                      title       date  year  \
# 0  Stardust in the Perseus Molecular Cloud 2021-03-18  2021
# 1        Hills, Ridges, and Tracks on Mars 2020-01-26  2020
# 2              Milky Way over Devils Tower 2022-04-13  2022
# 3       Perseverance Selfie with Ingenuity 2025-06-07  2025
# 4            A Note on the Perseus Cluster 2003-09-12  2003
#
#                                                  url  \
# 0  https://apod.nasa.gov/apod/image/2103/KerryLec...
# 1  https://apod.nasa.gov/apod/image/2001/HillsRid...
# 2  https://apod.nasa.gov/apod/image/2204/DevilsWa...
# 3  https://apod.nasa.gov/apod/image/2506/PIA24542...
# 4  https://apod.nasa.gov/apod/image/0309/perseus_...
#
#                                          explanation
# 0  Clouds of stardust drift through this deep sky...
# 1  Sometimes, even rovers on Mars stop to admire ...
# 2  What created Devils Tower? The origin of this ...
# 3  On the Mars rover's mission Sol 46 or Earth da...
# ...

# %%
df_extraction.to_csv("planets_date.csv", index=False)
print(r"C:\Users\dell\OneDrive\Documentos\9B UTXJ IDGS\planets_date.csv")
# Out:
# C:\Users\dell\OneDrive\Documentos\9B UTXJ IDGS\planets_date.csv
